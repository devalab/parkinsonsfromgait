# %%
import os
import random
import shutil
import tqdm
import numpy as np
import pandas as pd
import copy
import tensorflow as tf
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import *
from sklearn.impute import KNNImputer
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
from tensorflow.keras.activations import *
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import regularizers
import tensorflow.keras as keras
from tensorflow.keras.callbacks import EarlyStopping,ReduceLROnPlateau,ModelCheckpoint
from tensorflow.keras import layers, optimizers

import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline
# Out:
# /home/shanmukh.alle/miniconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/shanmukh.alle/miniconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/shanmukh.alle/miniconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/shanmukh.alle/miniconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/shanmukh.alle/miniconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/shanmukh.alle/miniconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
seed = 1
random.seed(seed)
np.random.seed(seed)
tf.set_random_seed(seed)
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"
import tensorflow as tf
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
session = tf.Session(config=config)
tf.keras.backend.set_session(session)

# %%
sampling_rate = 100
path = "../../dataset/processed100/force/"
# path = "../dataset/processed50/lp_residual/"
# path = "./dataset/raw/"
modelstore = "/scratch/shanmukh.alle/models"

# %%
walk_df = pd.read_csv("../../dataset/WalksDemographics.csv")
walk_df
# Out:
#          Walk Name Patient ID  Gender  Age  Height  Weight  HoehnYahr  UPDRS  \
# 0    GaCo01_01.txt     GaCo01       1   66    1.80    83.0        0.0    0.0
# 1    GaCo02_01.txt     GaCo02       1   74    1.74    70.0        0.0    1.0
# 2    GaCo02_02.txt     GaCo02       1   74    1.74    70.0        0.0    1.0
# 3    GaCo03_01.txt     GaCo03       1   69    1.80   101.0        0.0    0.0
# 4    GaCo03_02.txt     GaCo03       1   69    1.80   101.0        0.0    0.0
# ..             ...        ...     ...  ...     ...     ...        ...    ...
# 301  SiPt36_01.txt     SiPt36       2   53    1.58    62.0        2.0   52.0
# 302  SiPt37_01.txt     SiPt37       2   66    1.70    62.0        2.5   27.0
# 303  SiPt38_01.txt     SiPt38       2   65    1.59    60.0        2.0   22.0
# 304  SiPt39_01.txt     SiPt39       2   69    1.68    53.0        2.0   33.0
# 305  SiPt40_01.txt     SiPt40       1   69    1.60    81.0        2.5   37.0
#
#      UPDRSM   TUAG  Speed  Extra Task  Class
# 0       0.0    NaN  1.075           0      0
# 1       1.0    NaN  1.040           0      0
# 2       1.0    NaN  1.162           0      0
# 3       0.0    NaN  1.051           0      0
# 4       0.0    NaN  1.265           0      0
# ..      ...    ...    ...         ...    ...
# 301    32.0  11.27  0.970           0      1
# 302    21.0   7.56  1.010           0      1
# 303    14.0  10.13  1.070           0      1
# 304    20.0  13.97  0.880           0      1
# 305    24.0   9.70  1.070           0      1
#
# [306 rows x 13 columns]

# %%
data = {}
for i in set(walk_df["Patient ID"]):
    data[i] = []
    
for index,row in tqdm.tqdm(walk_df.iterrows()):
    patient = row["Patient ID"]
#     features = row[["Gender","Age","Height","Weight","TUAG","Speed","Extra Task"]]
    features = row[["Gender","Age","Height","Weight","TUAG"]]

    walk_name = row["Walk Name"]
    walk_seq = np.loadtxt(path+walk_name,delimiter=",")
    sample = (walk_seq,features,row["Class"])
    data[patient].append(sample)
# Out:
# 306it [00:38,  8.04it/s]

# %%
walk_seq.shape
# Out:
# (12119, 18)

# %%
patients = sorted(list(data.keys()))
labels = []
for i in patients:
    labels.append(walk_df[walk_df["Patient ID"]==i].iloc[0]["Class"])
#     print (i,labels[-1])

# %%
# Helper Functions

def window(samples,feature,label,cut_length=100):
    inputs = []
    features = []
    labels = []
    
    for i in range(len(samples)):
        sample = samples[i]
        cut = int(cut_length/2)
        for j in range(int(len(sample)/cut)):
            if (j+2)*cut>=len(sample):
                break
            inputs.append(sample[j*cut:(j+2)*cut,:])
            features.append(feature[i])
            labels.append(label[i])
            
    inputs = np.stack(inputs)
    features = np.array(features)
    labels = np.array(labels)
    
    return inputs, features, labels

def pad(samples):
    lengths = [len(i) for i in samples]
    max_len = max(lengths)
    for i in range(len(samples)):
        pad_len = max_len - lengths[i]
        samples[i] = np.pad(samples[i],((0,pad_len),(0,0)),"wrap")
    return np.stack(samples)
    
def get_from_dict(dictionary, keys):
    output = []
    for i in keys:
        output += dictionary[i]
    return output

def get_best_model(path):
    models = os.listdir(path)
    accuracy = {}
    for i in models:
        info = i.split("-")
        try:
            accuracy[float(info[-1][:-5])][float(info[-2])] = i
        except:
            accuracy[float(info[-1][:-5])] = {}
            accuracy[float(info[-1][:-5])][float(info[-2])] = i
    best_acc = max(accuracy.keys())
    best_loss = min(accuracy[best_acc].keys())
    model_path = accuracy[best_acc][best_loss]
    
    model = tf.keras.models.load_model(path+"/"+model_path)
    return model

class VariancePooling(tf.keras.layers.Layer):
    def __init__(self, ):
        super(VariancePooling, self).__init__()

    def call(self, x):
        return tf.math.reduce_std(x,axis=1)

# %%
def conv1D_full():
    '''
    :return: 1 branch of the parallel Convnet
    '''
    input1 = Input(shape=(100, 1))
    x = Conv1D(filters=8, kernel_size=3, activation='selu', padding='valid')(input1)
    x = Conv1D(filters=16, kernel_size=3, activation='selu', padding='valid')(x)
    x = layers.MaxPooling1D(2)(x)
    x = Conv1D(filters=16, kernel_size=3, activation='selu', padding='valid')(x)
    x = Conv1D(filters=16, kernel_size=3, activation='selu', padding='valid')(x)
    x = layers.MaxPooling1D(2)(x)
    x = layers.Flatten()(x)
    x = layers.Dense(50, activation='elu')(x)
    model = Model(input1, x)
    rms = optimizers.RMSprop(lr=0.001, decay=0.005)
    model.compile(loss='categorical_crossentropy', optimizer=rms, metrics=['accuracy'])
#     print(model.summary())
    return model


def multiple_cnn1D(nb=18):
    '''
    :param nb: number of features ( indicates the number of parallel branches)
    :return:
    '''
    inputs = Input(shape=(100,nb))
    outputs = []
    for i in range(nb):
        x = inputs[:,:,i]
        model = conv1D_full()
        x = tf.expand_dims(x,axis=-1)
        x = model(x)
        outputs.append(x)
    x = concatenate(outputs,axis=-1)
    x = Dropout(0.5)(x)
    x = layers.Dense(100, activation='selu')(x)
    x =  Dropout(0.5)(x)
    x = layers.Dense(20, activation='selu')(x)
    x = Dropout(0.5)(x)
    answer = layers.Dense(1, activation='sigmoid')(x)
    model = Model(inputs, answer)
    opt = optimizers.RMSprop(lr=0.001)
    model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])
#     print(model.summary())
    return model

def baseline(np=18):
        # Define Model
    input_layer = Input(shape=(None,18))
    x = SpatialDropout1D(0.2)(input_layer)
    x = Conv1D(32,7,activation="linear")(x)
    x = BatchNormalization()(x)
    x = Activation("elu")(x)
    x = MaxPool1D(2,2)(x)
    x = Conv1D(32,5,activation="linear")(x)
    x = BatchNormalization()(x)
    x = Activation("elu")(x)
    x = MaxPool1D(2,2)(x)
    x = Conv1D(64,3,activation="linear")(x)
    x = BatchNormalization()(x)
    x = Activation("elu",name="embedding")(x)
    avg_pool = GlobalAvgPool1D()(x)
    avg_pool = Dropout(0.25)(avg_pool)
    
    prediction = Dense(1,activation="sigmoid",name="det")(avg_pool)
    model = Model(inputs=input_layer, outputs=prediction)
    
    model.compile(optimizer=keras.optimizers.Adam(lr=0.001),
          loss=keras.losses.BinaryCrossentropy(label_smoothing=0.1),
          metrics=['accuracy'])
    return model

# %%
kfold = StratifiedKFold(n_splits=10,shuffle=True,random_state=0)
gold = []
predictions = []
AUC = []
accuracy = []
F1Score = []

fold = 0
try:
    shutil.rmtree(modelstore)
except:
    pass

for trainI,testI in kfold.split(patients,labels):
    fold+=1
    train_patients = [patients[i] for i in trainI]
    test_patients = [patients[i] for i in testI]
    print (test_patients)
    
    # Get Walk level data
    train = get_from_dict(data,train_patients)
    test = get_from_dict(data,test_patients)
    
    trainSeq = [i[0] for i in train]
    trainNum = [i[1].values for i in train]
    trainLabel = [i[2] for i in train]

    testSeq = [i[0] for i in test]
    testNum = [i[1].values for i in test]
    testLabel = [i[2] for i in test]
    
    # Normalize Numerical data
    scaler = StandardScaler()
    trainNum = scaler.fit_transform(trainNum)
    testNum = scaler.transform(testNum)
    
    # Impute Numerical data
    imputer = KNNImputer()
    trainNum = imputer.fit_transform(trainNum)
    testNum = imputer.transform(testNum)
    
    # Get Windowed Version of Input
    trainSeqWindows, trainNumWindows, trainLabelWindows = window(trainSeq,trainNum,trainLabel) 
    testSeqWindows, testNumWindows, testLabelWindows = window(testSeq,testNum,testLabel) 

    # Get Padded Version of Input
    trainSeqPadded = pad(trainSeq)
    testSeqPadded = pad(testSeq)
    
    # Define Model
#     full_model = multiple_cnn1D()
    full_model = baseline()
#     full_model.evaluate(testSeqWindows,testLabelWindows)
#     full_model.load_weights("temp.h5")
#     full_model.evaluate(testSeqWindows,testLabelWindows)
#     opt = optimizers.RMSprop(lr=0.001)
#     full_model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])
    earlystopper = EarlyStopping(monitor="val_loss",mode="min",patience=20, restore_best_weights=True,verbose=1, min_delta=0.01)
    reduce_lr = ReduceLROnPlateau(monitor="val_loss",factor=0.5,mode="min",patience=14,verbose=1,min_lr=0.0000001)
    
    full_model.fit(trainSeqWindows,trainLabelWindows,batch_size=800,epochs=1000,
              validation_data=[testSeqWindows,testLabelWindows],
              callbacks=[earlystopper,reduce_lr],verbose=1)
    
    prob = []
    binary = []
    for i in range(len(testSeq)):
        pred = full_model.predict(window([testSeq[i]],[testNum[i]],[testLabel[i]])[0])
        prediction = np.mean(pred)
        predictions.append(prediction)
        prob.append(prediction)
        if prediction>0.5:
            binary.append(1)
        else:
            binary.append(0)
        gold.append(testLabel[i])
        
    AUC.append(roc_auc_score(testLabel,prob))
    accuracy.append(accuracy_score(testLabel,binary))
    F1Score.append(f1_score(testLabel,binary))
    print (AUC[-1],accuracy[-1],F1Score[-1])
    # Cleanup
#     del full_model
#     del model
#     break
print ("AUC\t\t",np.mean(AUC),np.std(AUC))
print ("Accuracy\t",np.mean(accuracy),np.std(accuracy))
print ("F1Score\t\t",np.mean(F1Score),np.std(F1Score))
# Out:
# WARNING:tensorflow:From /home/shanmukh.alle/miniconda3/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /home/shanmukh.alle/miniconda3/lib/python3.7/site-packages/tensorflow_core/python/keras/backend.py:4277: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# ['GaCo07', 'GaPt06', 'GaPt08', 'GaPt12', 'GaPt26', 'JuCo02', 'JuCo05', 'JuCo08', 'JuCo25', 'JuPt08', 'JuPt19', 'SiCo01', 'SiCo16', 'SiCo21', 'SiPt28', 'SiPt31', 'SiPt39']
# Train on 61197 samples, validate on 4718 samples
# Epoch 1/1000
# 61197/61197 [==============================] - 4s 63us/sample - loss: 0.5730 - acc: 0.7275 - val_loss: 0.7910 - val_acc: 0.4358
# Epoch 2/1000
# 61197/61197 [==============================] - 1s 15us/sample - loss: 0.5014 - acc: 0.8039 - val_loss: 0.6899 - val_acc: 0.6471
# Epoch 3/1000
# 61197/61197 [==============================] - 1s 15us/sample - loss: 0.4826 - acc: 0.8216 - val_loss: 0.6376 - val_acc: 0.6751
# Epoch 4/1000
# 61197/61197 [==============================] - 1s 15us/sample - loss: 0.4685 - acc: 0.8320 - val_loss: 0.6054 - val_acc: 0.7384
# Epoch 5/1000
# 61197/61197 [==============================] - 1s 15us/sample - loss: 0.4595 - acc: 0.8401 - val_loss: 0.6597 - val_acc: 0.6634
# Epoch 6/1000
# 61197/61197 [==============================] - 1s 15us/sample - loss: 0.4443 - acc: 0.8495 - val_loss: 0.6342 - val_acc: 0.6939
# Epoch 7/1000
# 61197/61197 [==============================] - 1s 15us/sample - loss: 0.4343 - acc: 0.8554 - val_loss: 0.5808 - val_acc: 0.7416
# Epoch 8/1000
# 61197/61197 [==============================] - 1s 15us/sample - loss: 0.4260 - acc: 0.8614 - val_loss: 0.6423 - val_acc: 0.7031
# Epoch 9/1000
# 61197/61197 [==============================] - 1s 15us/sample - loss: 0.4205 - acc: 0.8645 - val_loss: 0.5207 - val_acc: 0.7683
# Epoch 10/1000
# 61197/61197 [==============================] - 1s 15us/sample - loss: 0.4111 - acc: 0.8709 - val_loss: 0.6114 - val_acc: 0.6992
# Epoch 11/1000
# 61197/61197 [==============================] - 1s 15us/sample - loss: 0.4063 - acc: 0.8741 - val_loss: 0.5795 - val_acc: 0.7575
# Epoch 12/1000
# 61197/61197 [==============================] - 1s 15us/sample - loss: 0.3997 - acc: 0.8792 - val_loss: 0.6052 - val_acc: 0.7060
# Epoch 13/1000
# 61197/61197 [==============================] - 1s 15us/sample - loss: 0.3953 - acc: 0.8811 - val_loss: 0.5754 - val_acc: 0.7563
# Epoch 14/1000
# 61197/61197 [==============================] - 1s 15us/sample - loss: 0.3916 - acc: 0.8829 - val_loss: 0.6510 - val_acc: 0.7298
# Epoch 15/1000
# 61197/61197 [==============================] - 1s 15us/sample - loss: 0.3871 - acc: 0.8864 - val_loss: 0.5841 - val_acc: 0.7552
# Epoch 16/1000
# 61197/61197 [==============================] - 1s 15us/sample - loss: 0.3832 - acc: 0.8905 - val_loss: 0.6079 - val_acc: 0.7647
# Epoch 17/1000
# 61197/61197 [==============================] - 1s 15us/sample - loss: 0.3799 - acc: 0.8930 - val_loss: 0.6482 - val_acc: 0.7232
# Epoch 18/1000
# 61197/61197 [==============================] - 1s 15us/sample - loss: 0.3794 - acc: 0.8934 - val_loss: 0.5976 - val_acc: 0.7109
# Epoch 19/1000
# 61197/61197 [==============================] - 1s 15us/sample - loss: 0.3734 - acc: 0.8979 - val_loss: 0.6437 - val_acc: 0.7031
# Epoch 20/1000
# 61197/61197 [==============================] - 1s 15us/sample - loss: 0.3704 - acc: 0.8992 - val_loss: 0.6359 - val_acc: 0.7168
# Epoch 21/1000
# 61197/61197 [==============================] - 1s 15us/sample - loss: 0.3667 - acc: 0.9013 - val_loss: 0.6948 - val_acc: 0.6621
# Epoch 22/1000
# 61197/61197 [==============================] - 1s 15us/sample - loss: 0.3648 - acc: 0.9033 - val_loss: 0.6288 - val_acc: 0.7130
# Epoch 23/1000
# 60800/61197 [============================>.] - ETA: 0s - loss: 0.3662 - acc: 0.9025
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 61197/61197 [==============================] - 1s 19us/sample - loss: 0.3661 - acc: 0.9025 - val_loss: 0.6326 - val_acc: 0.7232
# Epoch 24/1000
# 61197/61197 [==============================] - 1s 16us/sample - loss: 0.3558 - acc: 0.9082 - val_loss: 0.5587 - val_acc: 0.7529
# Epoch 25/1000
# 61197/61197 [==============================] - 1s 16us/sample - loss: 0.3527 - acc: 0.9117 - val_loss: 0.5987 - val_acc: 0.7251
# Epoch 26/1000
# 61197/61197 [==============================] - 1s 16us/sample - loss: 0.3524 - acc: 0.9123 - val_loss: 0.6365 - val_acc: 0.6916
# Epoch 27/1000
# 61197/61197 [==============================] - 1s 17us/sample - loss: 0.3521 - acc: 0.9121 - val_loss: 0.6258 - val_acc: 0.7189
# Epoch 28/1000
# 61197/61197 [==============================] - 1s 18us/sample - loss: 0.3509 - acc: 0.9142 - val_loss: 0.5968 - val_acc: 0.7232
# Epoch 29/1000
# 59200/61197 [============================>.] - ETA: 0s - loss: 0.3496 - acc: 0.9125Restoring model weights from the end of the best epoch.
# 61197/61197 [==============================] - 1s 22us/sample - loss: 0.3493 - acc: 0.9129 - val_loss: 0.5950 - val_acc: 0.7302
# Epoch 00029: early stopping
# 0.9401709401709403 0.8181818181818182 0.8571428571428571
# ['JuCo07', 'JuCo12', 'JuCo18', 'JuCo26', 'JuPt02', 'JuPt05', 'JuPt11', 'JuPt23', 'JuPt25', 'SiCo06', 'SiCo07', 'SiCo18', 'SiCo25', 'SiPt20', 'SiPt24', 'SiPt36', 'SiPt38']
# Train on 59983 samples, validate on 5932 samples
# Epoch 1/1000
# 59983/59983 [==============================] - 2s 38us/sample - loss: 0.5734 - acc: 0.7350 - val_loss: 0.5842 - val_acc: 0.6758
# Epoch 2/1000
# 59983/59983 [==============================] - 1s 16us/sample - loss: 0.5203 - acc: 0.7897 - val_loss: 0.5341 - val_acc: 0.7331
# Epoch 3/1000
# 59983/59983 [==============================] - 1s 16us/sample - loss: 0.4980 - acc: 0.8098 - val_loss: 0.5374 - val_acc: 0.7476
# Epoch 4/1000
# 59983/59983 [==============================] - 1s 16us/sample - loss: 0.4823 - acc: 0.8209 - val_loss: 0.5363 - val_acc: 0.7596
# Epoch 5/1000
# 59983/59983 [==============================] - 1s 16us/sample - loss: 0.4722 - acc: 0.8289 - val_loss: 0.4802 - val_acc: 0.8338
# Epoch 6/1000
# 59983/59983 [==============================] - 1s 19us/sample - loss: 0.4605 - acc: 0.8370 - val_loss: 0.4729 - val_acc: 0.8491
# Epoch 7/1000
# 59983/59983 [==============================] - 1s 19us/sample - loss: 0.4454 - acc: 0.8471 - val_loss: 0.4851 - val_acc: 0.8262
# Epoch 8/1000
# 59983/59983 [==============================] - 1s 18us/sample - loss: 0.4381 - acc: 0.8522 - val_loss: 0.4502 - val_acc: 0.8655
# Epoch 9/1000
# 59983/59983 [==============================] - 1s 17us/sample - loss: 0.4287 - acc: 0.8597 - val_loss: 0.4665 - val_acc: 0.8299
# Epoch 10/1000
# 59983/59983 [==============================] - 1s 17us/sample - loss: 0.4163 - acc: 0.8684 - val_loss: 0.4961 - val_acc: 0.8014
# Epoch 11/1000
# 59983/59983 [==============================] - 1s 17us/sample - loss: 0.4095 - acc: 0.8728 - val_loss: 0.4440 - val_acc: 0.8658
# Epoch 12/1000
# 59983/59983 [==============================] - 1s 17us/sample - loss: 0.4029 - acc: 0.8787 - val_loss: 0.4643 - val_acc: 0.8188
# Epoch 13/1000
# 59983/59983 [==============================] - 1s 20us/sample - loss: 0.3993 - acc: 0.8793 - val_loss: 0.4972 - val_acc: 0.7977
# Epoch 14/1000
# 59983/59983 [==============================] - 1s 18us/sample - loss: 0.3928 - acc: 0.8852 - val_loss: 0.4292 - val_acc: 0.8685
# Epoch 15/1000
# 59983/59983 [==============================] - 1s 16us/sample - loss: 0.3902 - acc: 0.8869 - val_loss: 0.4396 - val_acc: 0.8638
# Epoch 16/1000
# 59983/59983 [==============================] - 1s 17us/sample - loss: 0.3848 - acc: 0.8905 - val_loss: 0.4756 - val_acc: 0.8481
# Epoch 17/1000
# 59983/59983 [==============================] - 1s 17us/sample - loss: 0.3824 - acc: 0.8911 - val_loss: 0.4719 - val_acc: 0.8517
# Epoch 18/1000
# 59983/59983 [==============================] - 1s 18us/sample - loss: 0.3762 - acc: 0.8961 - val_loss: 0.4556 - val_acc: 0.8412
# Epoch 19/1000
# 59983/59983 [==============================] - 1s 21us/sample - loss: 0.3754 - acc: 0.8966 - val_loss: 0.4331 - val_acc: 0.8764
# Epoch 20/1000
# 59983/59983 [==============================] - 1s 17us/sample - loss: 0.3691 - acc: 0.9021 - val_loss: 0.4537 - val_acc: 0.8552
# Epoch 21/1000
# 59983/59983 [==============================] - 1s 17us/sample - loss: 0.3666 - acc: 0.9026 - val_loss: 0.4405 - val_acc: 0.8486
# Epoch 22/1000
# 59983/59983 [==============================] - 1s 17us/sample - loss: 0.3662 - acc: 0.9027 - val_loss: 0.4319 - val_acc: 0.8533
# Epoch 23/1000
# 59983/59983 [==============================] - 1s 17us/sample - loss: 0.3617 - acc: 0.9062 - val_loss: 0.4631 - val_acc: 0.8279
# Epoch 24/1000
# 59983/59983 [==============================] - 1s 17us/sample - loss: 0.3583 - acc: 0.9080 - val_loss: 0.4349 - val_acc: 0.8720
# Epoch 25/1000
# 59983/59983 [==============================] - 1s 17us/sample - loss: 0.3609 - acc: 0.9079 - val_loss: 0.4343 - val_acc: 0.8705
# Epoch 26/1000
# 59983/59983 [==============================] - 1s 17us/sample - loss: 0.3581 - acc: 0.9090 - val_loss: 0.4461 - val_acc: 0.8537
# Epoch 27/1000
# 59983/59983 [==============================] - 1s 19us/sample - loss: 0.3532 - acc: 0.9122 - val_loss: 0.4987 - val_acc: 0.8004
# Epoch 28/1000
# 58400/59983 [============================>.] - ETA: 0s - loss: 0.3518 - acc: 0.9125
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 59983/59983 [==============================] - 2s 25us/sample - loss: 0.3517 - acc: 0.9124 - val_loss: 0.4734 - val_acc: 0.8314
# Epoch 29/1000
# 59983/59983 [==============================] - 1s 18us/sample - loss: 0.3442 - acc: 0.9199 - val_loss: 0.4399 - val_acc: 0.8518
# Epoch 30/1000
# 59983/59983 [==============================] - 1s 16us/sample - loss: 0.3441 - acc: 0.9187 - val_loss: 0.4677 - val_acc: 0.8387
# Epoch 31/1000
# 59983/59983 [==============================] - 1s 17us/sample - loss: 0.3403 - acc: 0.9213 - val_loss: 0.4679 - val_acc: 0.8326
# Epoch 32/1000
# 59983/59983 [==============================] - 1s 17us/sample - loss: 0.3433 - acc: 0.9197 - val_loss: 0.4793 - val_acc: 0.8338
# Epoch 33/1000
# 59983/59983 [==============================] - 1s 17us/sample - loss: 0.3434 - acc: 0.9183 - val_loss: 0.4560 - val_acc: 0.8407
# Epoch 34/1000
# 58400/59983 [============================>.] - ETA: 0s - loss: 0.3404 - acc: 0.9213Restoring model weights from the end of the best epoch.
# 59983/59983 [==============================] - 1s 24us/sample - loss: 0.3412 - acc: 0.9209 - val_loss: 0.4591 - val_acc: 0.8491
# Epoch 00034: early stopping
# 0.9107142857142857 0.9310344827586207 0.9545454545454545
# ['GaCo04', 'GaPt03', 'GaPt07', 'GaPt27', 'JuCo20', 'JuCo24', 'JuPt03', 'JuPt06', 'JuPt10', 'JuPt14', 'JuPt26', 'SiCo03', 'SiCo04', 'SiCo10', 'SiCo24', 'SiPt21', 'SiPt23']
# Train on 57818 samples, validate on 8097 samples
# Epoch 1/1000
# 57818/57818 [==============================] - 2s 40us/sample - loss: 0.5877 - acc: 0.7124 - val_loss: 0.7163 - val_acc: 0.5876
# Epoch 2/1000
# 57818/57818 [==============================] - 1s 20us/sample - loss: 0.5201 - acc: 0.7891 - val_loss: 0.5632 - val_acc: 0.7492
# Epoch 3/1000
# 57818/57818 [==============================] - 1s 17us/sample - loss: 0.4942 - acc: 0.8131 - val_loss: 0.5100 - val_acc: 0.8007
# Epoch 4/1000
# 57818/57818 [==============================] - 1s 16us/sample - loss: 0.4832 - acc: 0.8222 - val_loss: 0.4896 - val_acc: 0.8214
# Epoch 5/1000
# 57818/57818 [==============================] - 1s 16us/sample - loss: 0.4700 - acc: 0.8301 - val_loss: 0.4671 - val_acc: 0.8380
# Epoch 6/1000
# 57818/57818 [==============================] - 1s 16us/sample - loss: 0.4567 - acc: 0.8406 - val_loss: 0.4675 - val_acc: 0.8381
# Epoch 7/1000
# 57818/57818 [==============================] - 1s 16us/sample - loss: 0.4443 - acc: 0.8500 - val_loss: 0.4692 - val_acc: 0.8493
# Epoch 8/1000
# 57818/57818 [==============================] - 1s 16us/sample - loss: 0.4390 - acc: 0.8540 - val_loss: 0.4731 - val_acc: 0.8278
# Epoch 9/1000
# 57818/57818 [==============================] - 1s 16us/sample - loss: 0.4286 - acc: 0.8609 - val_loss: 0.4984 - val_acc: 0.8243
# Epoch 10/1000
# 57818/57818 [==============================] - 1s 17us/sample - loss: 0.4234 - acc: 0.8635 - val_loss: 0.5227 - val_acc: 0.7526
# Epoch 11/1000
# 57818/57818 [==============================] - 1s 20us/sample - loss: 0.4171 - acc: 0.8685 - val_loss: 0.4880 - val_acc: 0.8013
# Epoch 12/1000
# 57818/57818 [==============================] - 1s 17us/sample - loss: 0.4090 - acc: 0.8746 - val_loss: 0.6825 - val_acc: 0.6047
# Epoch 13/1000
# 57818/57818 [==============================] - 1s 16us/sample - loss: 0.4048 - acc: 0.8784 - val_loss: 0.5248 - val_acc: 0.7629
# Epoch 14/1000
# 57818/57818 [==============================] - 1s 16us/sample - loss: 0.4050 - acc: 0.8755 - val_loss: 0.4712 - val_acc: 0.8206
# Epoch 15/1000
# 57818/57818 [==============================] - 1s 17us/sample - loss: 0.3941 - acc: 0.8848 - val_loss: 0.6111 - val_acc: 0.6707
# Epoch 16/1000
# 57818/57818 [==============================] - 1s 17us/sample - loss: 0.3919 - acc: 0.8859 - val_loss: 0.6192 - val_acc: 0.6572
# Epoch 17/1000
# 57818/57818 [==============================] - 1s 17us/sample - loss: 0.3841 - acc: 0.8903 - val_loss: 0.5170 - val_acc: 0.7634
# Epoch 18/1000
# 57818/57818 [==============================] - 1s 18us/sample - loss: 0.3809 - acc: 0.8917 - val_loss: 0.5134 - val_acc: 0.7800
# Epoch 19/1000
# 55200/57818 [===========================>..] - ETA: 0s - loss: 0.3828 - acc: 0.8909
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 57818/57818 [==============================] - 1s 26us/sample - loss: 0.3823 - acc: 0.8909 - val_loss: 0.5056 - val_acc: 0.7849
# Epoch 20/1000
# 57818/57818 [==============================] - 1s 17us/sample - loss: 0.3683 - acc: 0.9008 - val_loss: 0.5524 - val_acc: 0.7246
# Epoch 21/1000
# 57818/57818 [==============================] - 1s 18us/sample - loss: 0.3662 - acc: 0.9019 - val_loss: 0.5236 - val_acc: 0.7588
# Epoch 22/1000
# 57818/57818 [==============================] - 1s 18us/sample - loss: 0.3643 - acc: 0.9026 - val_loss: 0.5567 - val_acc: 0.7271
# Epoch 23/1000
# 57818/57818 [==============================] - 1s 19us/sample - loss: 0.3609 - acc: 0.9060 - val_loss: 0.5407 - val_acc: 0.7530
# Epoch 24/1000
# 57818/57818 [==============================] - 1s 17us/sample - loss: 0.3632 - acc: 0.9034 - val_loss: 0.5766 - val_acc: 0.7219
# Epoch 25/1000
# 56800/57818 [============================>.] - ETA: 0s - loss: 0.3587 - acc: 0.9072Restoring model weights from the end of the best epoch.
# 57818/57818 [==============================] - 2s 27us/sample - loss: 0.3585 - acc: 0.9073 - val_loss: 0.5689 - val_acc: 0.7216
# Epoch 00025: early stopping
# 0.8680555555555556 0.9090909090909091 0.9473684210526316
# ['GaCo01', 'GaCo02', 'GaCo12', 'GaPt21', 'GaPt22', 'GaPt24', 'GaPt29', 'GaPt30', 'JuCo21', 'JuPt16', 'SiCo08', 'SiCo20', 'SiCo22', 'SiPt07', 'SiPt09', 'SiPt10', 'SiPt15']
# Train on 59176 samples, validate on 6739 samples
# Epoch 1/1000
# 59176/59176 [==============================] - 3s 49us/sample - loss: 0.5830 - acc: 0.7184 - val_loss: 0.5895 - val_acc: 0.7350
# Epoch 2/1000
# 59176/59176 [==============================] - 1s 16us/sample - loss: 0.5204 - acc: 0.7906 - val_loss: 0.5253 - val_acc: 0.7715
# Epoch 3/1000
# 59176/59176 [==============================] - 1s 16us/sample - loss: 0.4924 - acc: 0.8123 - val_loss: 0.5053 - val_acc: 0.7902
# Epoch 4/1000
# 59176/59176 [==============================] - 1s 16us/sample - loss: 0.4719 - acc: 0.8322 - val_loss: 0.5685 - val_acc: 0.7750
# Epoch 5/1000
# 59176/59176 [==============================] - 1s 16us/sample - loss: 0.4566 - acc: 0.8422 - val_loss: 0.5201 - val_acc: 0.7918
# Epoch 6/1000
# 59176/59176 [==============================] - 1s 16us/sample - loss: 0.4459 - acc: 0.8488 - val_loss: 0.5327 - val_acc: 0.8058
# Epoch 7/1000
# 59176/59176 [==============================] - 1s 16us/sample - loss: 0.4309 - acc: 0.8591 - val_loss: 0.5224 - val_acc: 0.7764
# Epoch 8/1000
# 59176/59176 [==============================] - 1s 16us/sample - loss: 0.4201 - acc: 0.8665 - val_loss: 0.5268 - val_acc: 0.7789
# Epoch 9/1000
# 59176/59176 [==============================] - 1s 16us/sample - loss: 0.4112 - acc: 0.8718 - val_loss: 0.5214 - val_acc: 0.7810
# Epoch 10/1000
# 59176/59176 [==============================] - 1s 18us/sample - loss: 0.4068 - acc: 0.8747 - val_loss: 0.6095 - val_acc: 0.7308
# Epoch 11/1000
# 59176/59176 [==============================] - 1s 19us/sample - loss: 0.4029 - acc: 0.8777 - val_loss: 0.5573 - val_acc: 0.7657
# Epoch 12/1000
# 59176/59176 [==============================] - 1s 16us/sample - loss: 0.3961 - acc: 0.8826 - val_loss: 0.6030 - val_acc: 0.7141
# Epoch 13/1000
# 59176/59176 [==============================] - 1s 16us/sample - loss: 0.3893 - acc: 0.8875 - val_loss: 0.5790 - val_acc: 0.7448
# Epoch 14/1000
# 59176/59176 [==============================] - 1s 16us/sample - loss: 0.3874 - acc: 0.8875 - val_loss: 0.5837 - val_acc: 0.7399
# Epoch 15/1000
# 59176/59176 [==============================] - 1s 16us/sample - loss: 0.3876 - acc: 0.8883 - val_loss: 0.5795 - val_acc: 0.7425
# Epoch 16/1000
# 59176/59176 [==============================] - 1s 16us/sample - loss: 0.3804 - acc: 0.8931 - val_loss: 0.6201 - val_acc: 0.7308
# Epoch 17/1000
# 56800/59176 [===========================>..] - ETA: 0s - loss: 0.3780 - acc: 0.8946
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 59176/59176 [==============================] - 1s 23us/sample - loss: 0.3775 - acc: 0.8950 - val_loss: 0.5452 - val_acc: 0.7621
# Epoch 18/1000
# 59176/59176 [==============================] - 1s 16us/sample - loss: 0.3654 - acc: 0.9030 - val_loss: 0.6085 - val_acc: 0.7339
# Epoch 19/1000
# 59176/59176 [==============================] - 1s 16us/sample - loss: 0.3645 - acc: 0.9036 - val_loss: 0.5585 - val_acc: 0.7685
# Epoch 20/1000
# 59176/59176 [==============================] - 1s 16us/sample - loss: 0.3634 - acc: 0.9050 - val_loss: 0.5722 - val_acc: 0.7471
# Epoch 21/1000
# 59176/59176 [==============================] - 1s 15us/sample - loss: 0.3614 - acc: 0.9061 - val_loss: 0.5591 - val_acc: 0.7543
# Epoch 22/1000
# 59176/59176 [==============================] - 1s 17us/sample - loss: 0.3603 - acc: 0.9069 - val_loss: 0.5703 - val_acc: 0.7463
# Epoch 23/1000
# 56000/59176 [===========================>..] - ETA: 0s - loss: 0.3577 - acc: 0.9096Restoring model weights from the end of the best epoch.
# 59176/59176 [==============================] - 1s 25us/sample - loss: 0.3572 - acc: 0.9097 - val_loss: 0.5635 - val_acc: 0.7587
# Epoch 00023: early stopping
# 0.86875 0.7857142857142857 0.8695652173913044
# ['GaCo05', 'GaCo09', 'GaCo13', 'GaCo15', 'GaPt09', 'GaPt19', 'GaPt20', 'GaPt33', 'JuCo17', 'JuCo23', 'JuPt13', 'JuPt21', 'JuPt27', 'SiCo23', 'SiPt16', 'SiPt29', 'SiPt35']
# Train on 56769 samples, validate on 9146 samples
# Epoch 1/1000
# 56769/56769 [==============================] - 3s 48us/sample - loss: 0.5856 - acc: 0.7158 - val_loss: 0.5395 - val_acc: 0.7743
# Epoch 2/1000
# 56769/56769 [==============================] - 1s 16us/sample - loss: 0.5197 - acc: 0.7921 - val_loss: 0.5332 - val_acc: 0.7357
# Epoch 3/1000
# 56769/56769 [==============================] - 1s 15us/sample - loss: 0.4958 - acc: 0.8113 - val_loss: 0.5535 - val_acc: 0.7210
# Epoch 4/1000
# 56769/56769 [==============================] - 1s 16us/sample - loss: 0.4782 - acc: 0.8255 - val_loss: 0.5471 - val_acc: 0.7482
# Epoch 5/1000
# 56769/56769 [==============================] - 1s 16us/sample - loss: 0.4610 - acc: 0.8375 - val_loss: 0.5524 - val_acc: 0.7386
# Epoch 6/1000
# 56769/56769 [==============================] - 1s 16us/sample - loss: 0.4464 - acc: 0.8474 - val_loss: 0.5569 - val_acc: 0.7451
# Epoch 7/1000
# 56769/56769 [==============================] - 1s 16us/sample - loss: 0.4360 - acc: 0.8560 - val_loss: 0.5950 - val_acc: 0.7529
# Epoch 8/1000
# 56769/56769 [==============================] - 1s 16us/sample - loss: 0.4302 - acc: 0.8593 - val_loss: 0.5701 - val_acc: 0.7595
# Epoch 9/1000
# 56769/56769 [==============================] - 1s 16us/sample - loss: 0.4234 - acc: 0.8634 - val_loss: 0.5602 - val_acc: 0.7713
# Epoch 10/1000
# 56769/56769 [==============================] - 1s 16us/sample - loss: 0.4173 - acc: 0.8669 - val_loss: 0.5365 - val_acc: 0.7822
# Epoch 11/1000
# 56769/56769 [==============================] - 1s 16us/sample - loss: 0.4109 - acc: 0.8724 - val_loss: 0.5435 - val_acc: 0.7800
# Epoch 12/1000
# 56769/56769 [==============================] - 1s 16us/sample - loss: 0.4016 - acc: 0.8780 - val_loss: 0.5456 - val_acc: 0.7569
# Epoch 13/1000
# 56769/56769 [==============================] - 1s 16us/sample - loss: 0.4003 - acc: 0.8790 - val_loss: 0.5923 - val_acc: 0.7496
# Epoch 14/1000
# 56769/56769 [==============================] - 1s 16us/sample - loss: 0.3935 - acc: 0.8845 - val_loss: 0.5987 - val_acc: 0.7417
# Epoch 15/1000
# 56769/56769 [==============================] - 1s 16us/sample - loss: 0.3923 - acc: 0.8856 - val_loss: 0.5935 - val_acc: 0.7628
# Epoch 16/1000
# 52800/56769 [==========================>...] - ETA: 0s - loss: 0.3871 - acc: 0.8861
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 56769/56769 [==============================] - 1s 24us/sample - loss: 0.3870 - acc: 0.8864 - val_loss: 0.5737 - val_acc: 0.7704
# Epoch 17/1000
# 56769/56769 [==============================] - 1s 16us/sample - loss: 0.3773 - acc: 0.8955 - val_loss: 0.6282 - val_acc: 0.7139
# Epoch 18/1000
# 56769/56769 [==============================] - 1s 16us/sample - loss: 0.3753 - acc: 0.8964 - val_loss: 0.5651 - val_acc: 0.7700
# Epoch 19/1000
# 56769/56769 [==============================] - 1s 16us/sample - loss: 0.3724 - acc: 0.8981 - val_loss: 0.6658 - val_acc: 0.7030
# Epoch 20/1000
# 56769/56769 [==============================] - 1s 16us/sample - loss: 0.3711 - acc: 0.8999 - val_loss: 0.6480 - val_acc: 0.7193
# Epoch 21/1000
# 52800/56769 [==========================>...] - ETA: 0s - loss: 0.3707 - acc: 0.8991Restoring model weights from the end of the best epoch.
# 56769/56769 [==============================] - 1s 25us/sample - loss: 0.3701 - acc: 0.8996 - val_loss: 0.6290 - val_acc: 0.7205
# Epoch 00021: early stopping
# 0.94314381270903 0.75 0.8363636363636363
# ['GaCo14', 'GaPt13', 'GaPt14', 'GaPt18', 'JuCo01', 'JuCo06', 'JuCo13', 'JuPt07', 'SiCo09', 'SiCo14', 'SiCo15', 'SiPt12', 'SiPt18', 'SiPt19', 'SiPt25', 'SiPt37']
# Train on 60492 samples, validate on 5423 samples
# Epoch 1/1000
# 60492/60492 [==============================] - 3s 52us/sample - loss: 0.5989 - acc: 0.6997 - val_loss: 0.6645 - val_acc: 0.6295
# Epoch 2/1000
# 60492/60492 [==============================] - 1s 18us/sample - loss: 0.5212 - acc: 0.7878 - val_loss: 0.6316 - val_acc: 0.6452
# Epoch 3/1000
# 60492/60492 [==============================] - 1s 17us/sample - loss: 0.4942 - acc: 0.8124 - val_loss: 0.6174 - val_acc: 0.6592
# Epoch 4/1000
# 60492/60492 [==============================] - 1s 18us/sample - loss: 0.4763 - acc: 0.8266 - val_loss: 0.6072 - val_acc: 0.6948
# Epoch 5/1000
# 60492/60492 [==============================] - 1s 17us/sample - loss: 0.4626 - acc: 0.8359 - val_loss: 0.5711 - val_acc: 0.7424
# Epoch 6/1000
# 60492/60492 [==============================] - 1s 17us/sample - loss: 0.4489 - acc: 0.8465 - val_loss: 0.5782 - val_acc: 0.7470
# Epoch 7/1000
# 60492/60492 [==============================] - 1s 17us/sample - loss: 0.4391 - acc: 0.8527 - val_loss: 0.5423 - val_acc: 0.7699
# Epoch 8/1000
# 60492/60492 [==============================] - 1s 17us/sample - loss: 0.4262 - acc: 0.8630 - val_loss: 0.5173 - val_acc: 0.7937
# Epoch 9/1000
# 60492/60492 [==============================] - 1s 17us/sample - loss: 0.4209 - acc: 0.8641 - val_loss: 0.5052 - val_acc: 0.8206
# Epoch 10/1000
# 60492/60492 [==============================] - 1s 17us/sample - loss: 0.4149 - acc: 0.8693 - val_loss: 0.5308 - val_acc: 0.7866
# Epoch 11/1000
# 60492/60492 [==============================] - 1s 17us/sample - loss: 0.4064 - acc: 0.8749 - val_loss: 0.5350 - val_acc: 0.7859
# Epoch 12/1000
# 60492/60492 [==============================] - 1s 17us/sample - loss: 0.3972 - acc: 0.8827 - val_loss: 0.4861 - val_acc: 0.8219
# Epoch 13/1000
# 60492/60492 [==============================] - 1s 17us/sample - loss: 0.3958 - acc: 0.8823 - val_loss: 0.4908 - val_acc: 0.8141
# Epoch 14/1000
# 60492/60492 [==============================] - 1s 17us/sample - loss: 0.3903 - acc: 0.8853 - val_loss: 0.5303 - val_acc: 0.8018
# Epoch 15/1000
# 60492/60492 [==============================] - 1s 17us/sample - loss: 0.3916 - acc: 0.8851 - val_loss: 0.5149 - val_acc: 0.8119
# Epoch 16/1000
# 60492/60492 [==============================] - 1s 17us/sample - loss: 0.3846 - acc: 0.8904 - val_loss: 0.5160 - val_acc: 0.8077
# Epoch 17/1000
# 60492/60492 [==============================] - 1s 17us/sample - loss: 0.3772 - acc: 0.8955 - val_loss: 0.4959 - val_acc: 0.8154
# Epoch 18/1000
# 60492/60492 [==============================] - 1s 17us/sample - loss: 0.3738 - acc: 0.8982 - val_loss: 0.4908 - val_acc: 0.8248
# Epoch 19/1000
# 60492/60492 [==============================] - 1s 17us/sample - loss: 0.3724 - acc: 0.8986 - val_loss: 0.4652 - val_acc: 0.8372
# Epoch 20/1000
# 60492/60492 [==============================] - 1s 17us/sample - loss: 0.3664 - acc: 0.9029 - val_loss: 0.4919 - val_acc: 0.8093
# Epoch 21/1000
# 60492/60492 [==============================] - 1s 17us/sample - loss: 0.3654 - acc: 0.9036 - val_loss: 0.4902 - val_acc: 0.8121
# Epoch 22/1000
# 60492/60492 [==============================] - 1s 18us/sample - loss: 0.3639 - acc: 0.9041 - val_loss: 0.4975 - val_acc: 0.8180
# Epoch 23/1000
# 60492/60492 [==============================] - 1s 18us/sample - loss: 0.3614 - acc: 0.9057 - val_loss: 0.4902 - val_acc: 0.8077
# Epoch 24/1000
# 60492/60492 [==============================] - 1s 17us/sample - loss: 0.3606 - acc: 0.9062 - val_loss: 0.4628 - val_acc: 0.8342
# Epoch 25/1000
# 60492/60492 [==============================] - 1s 18us/sample - loss: 0.3567 - acc: 0.9097 - val_loss: 0.5104 - val_acc: 0.7992
# Epoch 26/1000
# 60492/60492 [==============================] - 1s 18us/sample - loss: 0.3555 - acc: 0.9113 - val_loss: 0.4978 - val_acc: 0.8047
# Epoch 27/1000
# 60492/60492 [==============================] - 1s 18us/sample - loss: 0.3533 - acc: 0.9113 - val_loss: 0.5124 - val_acc: 0.7892
# Epoch 28/1000
# 60492/60492 [==============================] - 1s 17us/sample - loss: 0.3536 - acc: 0.9121 - val_loss: 0.4929 - val_acc: 0.8186
# Epoch 29/1000
# 60492/60492 [==============================] - 1s 17us/sample - loss: 0.3517 - acc: 0.9126 - val_loss: 0.4809 - val_acc: 0.8219
# Epoch 30/1000
# 60492/60492 [==============================] - 1s 17us/sample - loss: 0.3491 - acc: 0.9150 - val_loss: 0.4880 - val_acc: 0.8195
# Epoch 31/1000
# 60492/60492 [==============================] - 1s 17us/sample - loss: 0.3473 - acc: 0.9159 - val_loss: 0.5322 - val_acc: 0.7726
# Epoch 32/1000
# 60492/60492 [==============================] - 1s 17us/sample - loss: 0.3470 - acc: 0.9165 - val_loss: 0.4763 - val_acc: 0.8320
# Epoch 33/1000
# 60492/60492 [==============================] - 1s 17us/sample - loss: 0.3471 - acc: 0.9165 - val_loss: 0.4584 - val_acc: 0.8311
# Epoch 34/1000
# 60492/60492 [==============================] - 1s 17us/sample - loss: 0.3475 - acc: 0.9159 - val_loss: 0.5442 - val_acc: 0.7706
# Epoch 35/1000
# 60492/60492 [==============================] - 1s 17us/sample - loss: 0.3423 - acc: 0.9191 - val_loss: 0.4603 - val_acc: 0.8329
# Epoch 36/1000
# 60492/60492 [==============================] - 1s 17us/sample - loss: 0.3453 - acc: 0.9179 - val_loss: 0.4564 - val_acc: 0.8385
# Epoch 37/1000
# 60492/60492 [==============================] - 1s 17us/sample - loss: 0.3399 - acc: 0.9224 - val_loss: 0.4838 - val_acc: 0.8167
# Epoch 38/1000
# 60492/60492 [==============================] - 1s 17us/sample - loss: 0.3384 - acc: 0.9219 - val_loss: 0.4678 - val_acc: 0.8193
# Epoch 39/1000
# 58400/60492 [===========================>..] - ETA: 0s - loss: 0.3373 - acc: 0.9243Restoring model weights from the end of the best epoch.
# 60492/60492 [==============================] - 2s 28us/sample - loss: 0.3374 - acc: 0.9242 - val_loss: 0.4648 - val_acc: 0.8272
# Epoch 00039: early stopping
# 0.9333333333333333 0.875 0.9032258064516129
# ['GaCo03', 'GaPt25', 'GaPt32', 'JuCo04', 'JuCo11', 'JuCo14', 'JuPt15', 'JuPt18', 'JuPt22', 'JuPt28', 'SiCo12', 'SiCo29', 'SiCo30', 'SiPt04', 'SiPt14', 'SiPt22']
# Train on 58850 samples, validate on 7065 samples
# Epoch 1/1000
# 58850/58850 [==============================] - 3s 51us/sample - loss: 0.5829 - acc: 0.7195 - val_loss: 0.6624 - val_acc: 0.6316
# Epoch 2/1000
# 58850/58850 [==============================] - 1s 15us/sample - loss: 0.5212 - acc: 0.7853 - val_loss: 0.5349 - val_acc: 0.8314
# Epoch 3/1000
# 58850/58850 [==============================] - 1s 16us/sample - loss: 0.5022 - acc: 0.8033 - val_loss: 0.5121 - val_acc: 0.8318
# Epoch 4/1000
# 58850/58850 [==============================] - 1s 16us/sample - loss: 0.4865 - acc: 0.8146 - val_loss: 0.5134 - val_acc: 0.8364
# Epoch 5/1000
# 58850/58850 [==============================] - 1s 16us/sample - loss: 0.4751 - acc: 0.8242 - val_loss: 0.4635 - val_acc: 0.8831
# Epoch 6/1000
# 58850/58850 [==============================] - 1s 17us/sample - loss: 0.4601 - acc: 0.8364 - val_loss: 0.5258 - val_acc: 0.7849
# Epoch 7/1000
# 58850/58850 [==============================] - 1s 16us/sample - loss: 0.4454 - acc: 0.8461 - val_loss: 0.5100 - val_acc: 0.7895
# Epoch 8/1000
# 58850/58850 [==============================] - 1s 16us/sample - loss: 0.4359 - acc: 0.8532 - val_loss: 0.4689 - val_acc: 0.8545
# Epoch 9/1000
# 58850/58850 [==============================] - 1s 16us/sample - loss: 0.4272 - acc: 0.8603 - val_loss: 0.5162 - val_acc: 0.7691
# Epoch 10/1000
# 58850/58850 [==============================] - 1s 16us/sample - loss: 0.4159 - acc: 0.8679 - val_loss: 0.5481 - val_acc: 0.7568
# Epoch 11/1000
# 58850/58850 [==============================] - 1s 16us/sample - loss: 0.4107 - acc: 0.8708 - val_loss: 0.5250 - val_acc: 0.7541
# Epoch 12/1000
# 58850/58850 [==============================] - 1s 16us/sample - loss: 0.4022 - acc: 0.8788 - val_loss: 0.4964 - val_acc: 0.7918
# Epoch 13/1000
# 58850/58850 [==============================] - 1s 16us/sample - loss: 0.3977 - acc: 0.8803 - val_loss: 0.4367 - val_acc: 0.8459
# Epoch 14/1000
# 58850/58850 [==============================] - 1s 16us/sample - loss: 0.3907 - acc: 0.8851 - val_loss: 0.5833 - val_acc: 0.7233
# Epoch 15/1000
# 58850/58850 [==============================] - 1s 16us/sample - loss: 0.3910 - acc: 0.8850 - val_loss: 0.4170 - val_acc: 0.8651
# Epoch 16/1000
# 58850/58850 [==============================] - 1s 16us/sample - loss: 0.3839 - acc: 0.8912 - val_loss: 0.4434 - val_acc: 0.8381
# Epoch 17/1000
# 58850/58850 [==============================] - 1s 16us/sample - loss: 0.3852 - acc: 0.8900 - val_loss: 0.4574 - val_acc: 0.8297
# Epoch 18/1000
# 58850/58850 [==============================] - 1s 16us/sample - loss: 0.3799 - acc: 0.8930 - val_loss: 0.4238 - val_acc: 0.8527
# Epoch 19/1000
# 58850/58850 [==============================] - 1s 16us/sample - loss: 0.3742 - acc: 0.8977 - val_loss: 0.4781 - val_acc: 0.8188
# Epoch 20/1000
# 58850/58850 [==============================] - 1s 16us/sample - loss: 0.3768 - acc: 0.8946 - val_loss: 0.4133 - val_acc: 0.8653
# Epoch 21/1000
# 58850/58850 [==============================] - 1s 16us/sample - loss: 0.3680 - acc: 0.9016 - val_loss: 0.4260 - val_acc: 0.8576
# Epoch 22/1000
# 58850/58850 [==============================] - 1s 16us/sample - loss: 0.3667 - acc: 0.9027 - val_loss: 0.4178 - val_acc: 0.8623
# Epoch 23/1000
# 58850/58850 [==============================] - 1s 16us/sample - loss: 0.3655 - acc: 0.9029 - val_loss: 0.4547 - val_acc: 0.8372
# Epoch 24/1000
# 58850/58850 [==============================] - 1s 16us/sample - loss: 0.3616 - acc: 0.9051 - val_loss: 0.4575 - val_acc: 0.8344
# Epoch 25/1000
# 58850/58850 [==============================] - 1s 16us/sample - loss: 0.3599 - acc: 0.9072 - val_loss: 0.3938 - val_acc: 0.8831
# Epoch 26/1000
# 58850/58850 [==============================] - 1s 16us/sample - loss: 0.3593 - acc: 0.9069 - val_loss: 0.4091 - val_acc: 0.8705
# Epoch 27/1000
# 58850/58850 [==============================] - 1s 16us/sample - loss: 0.3605 - acc: 0.9067 - val_loss: 0.4094 - val_acc: 0.8711
# Epoch 28/1000
# 58850/58850 [==============================] - 1s 16us/sample - loss: 0.3567 - acc: 0.9092 - val_loss: 0.4237 - val_acc: 0.8541
# Epoch 29/1000
# 58850/58850 [==============================] - 1s 16us/sample - loss: 0.3538 - acc: 0.9118 - val_loss: 0.4001 - val_acc: 0.8736
# Epoch 30/1000
# 58850/58850 [==============================] - 1s 16us/sample - loss: 0.3548 - acc: 0.9102 - val_loss: 0.3920 - val_acc: 0.8837
# Epoch 31/1000
# 58850/58850 [==============================] - 1s 16us/sample - loss: 0.3497 - acc: 0.9144 - val_loss: 0.4067 - val_acc: 0.8746
# Epoch 32/1000
# 58850/58850 [==============================] - 1s 16us/sample - loss: 0.3516 - acc: 0.9130 - val_loss: 0.4469 - val_acc: 0.8442
# Epoch 33/1000
# 58850/58850 [==============================] - 1s 17us/sample - loss: 0.3509 - acc: 0.9123 - val_loss: 0.4099 - val_acc: 0.8671
# Epoch 34/1000
# 58850/58850 [==============================] - 1s 16us/sample - loss: 0.3498 - acc: 0.9145 - val_loss: 0.4270 - val_acc: 0.8594
# Epoch 35/1000
# 58850/58850 [==============================] - 1s 16us/sample - loss: 0.3460 - acc: 0.9163 - val_loss: 0.4212 - val_acc: 0.8586
# Epoch 36/1000
# 58850/58850 [==============================] - 1s 16us/sample - loss: 0.3432 - acc: 0.9190 - val_loss: 0.3948 - val_acc: 0.8818
# Epoch 37/1000
# 58850/58850 [==============================] - 1s 16us/sample - loss: 0.3439 - acc: 0.9187 - val_loss: 0.3915 - val_acc: 0.8811
# Epoch 38/1000
# 58850/58850 [==============================] - 1s 16us/sample - loss: 0.3438 - acc: 0.9170 - val_loss: 0.4715 - val_acc: 0.8160
# Epoch 39/1000
# 58850/58850 [==============================] - 1s 16us/sample - loss: 0.3408 - acc: 0.9206 - val_loss: 0.4757 - val_acc: 0.8200
# Epoch 40/1000
# 58850/58850 [==============================] - 1s 16us/sample - loss: 0.3402 - acc: 0.9224 - val_loss: 0.4140 - val_acc: 0.8696
# Epoch 41/1000
# 58850/58850 [==============================] - 1s 16us/sample - loss: 0.3411 - acc: 0.9195 - val_loss: 0.3949 - val_acc: 0.8851
# Epoch 42/1000
# 58850/58850 [==============================] - 1s 16us/sample - loss: 0.3392 - acc: 0.9215 - val_loss: 0.4277 - val_acc: 0.8556
# Epoch 43/1000
# 58850/58850 [==============================] - 1s 16us/sample - loss: 0.3405 - acc: 0.9200 - val_loss: 0.4635 - val_acc: 0.8311
# Epoch 44/1000
# 58850/58850 [==============================] - 1s 16us/sample - loss: 0.3378 - acc: 0.9231 - val_loss: 0.4254 - val_acc: 0.8559
# Epoch 45/1000
# 56800/58850 [===========================>..] - ETA: 0s - loss: 0.3333 - acc: 0.9257Restoring model weights from the end of the best epoch.
# 58850/58850 [==============================] - 2s 28us/sample - loss: 0.3333 - acc: 0.9255 - val_loss: 0.4039 - val_acc: 0.8756
# Epoch 00045: early stopping
# 0.98 0.9393939393939394 0.96
# ['GaCo06', 'GaCo11', 'GaCo16', 'GaPt05', 'GaPt23', 'GaPt28', 'JuCo09', 'JuCo15', 'JuCo16', 'JuCo22', 'JuPt20', 'JuPt24', 'JuPt29', 'SiPt08', 'SiPt17', 'SiPt32']
# Train on 58607 samples, validate on 7308 samples
# Epoch 1/1000
# 58607/58607 [==============================] - 3s 51us/sample - loss: 0.5866 - acc: 0.7112 - val_loss: 0.6622 - val_acc: 0.5638
# Epoch 2/1000
# 58607/58607 [==============================] - 1s 18us/sample - loss: 0.5082 - acc: 0.8023 - val_loss: 0.5930 - val_acc: 0.7477
# Epoch 3/1000
# 58607/58607 [==============================] - 1s 17us/sample - loss: 0.4849 - acc: 0.8199 - val_loss: 0.5954 - val_acc: 0.7482
# Epoch 4/1000
# 58607/58607 [==============================] - 1s 17us/sample - loss: 0.4689 - acc: 0.8336 - val_loss: 0.6089 - val_acc: 0.7477
# Epoch 5/1000
# 58607/58607 [==============================] - 1s 17us/sample - loss: 0.4548 - acc: 0.8413 - val_loss: 0.5960 - val_acc: 0.7867
# Epoch 6/1000
# 58607/58607 [==============================] - 1s 17us/sample - loss: 0.4433 - acc: 0.8490 - val_loss: 0.6439 - val_acc: 0.6998
# Epoch 7/1000
# 58607/58607 [==============================] - 1s 17us/sample - loss: 0.4366 - acc: 0.8535 - val_loss: 0.6157 - val_acc: 0.7645
# Epoch 8/1000
# 58607/58607 [==============================] - 1s 17us/sample - loss: 0.4242 - acc: 0.8631 - val_loss: 0.6300 - val_acc: 0.7375
# Epoch 9/1000
# 58607/58607 [==============================] - 1s 17us/sample - loss: 0.4161 - acc: 0.8679 - val_loss: 0.7157 - val_acc: 0.6407
# Epoch 10/1000
# 58607/58607 [==============================] - 1s 17us/sample - loss: 0.4031 - acc: 0.8766 - val_loss: 0.7304 - val_acc: 0.6348
# Epoch 11/1000
# 58607/58607 [==============================] - 1s 17us/sample - loss: 0.4044 - acc: 0.8753 - val_loss: 0.7005 - val_acc: 0.6709
# Epoch 12/1000
# 58607/58607 [==============================] - 1s 17us/sample - loss: 0.3961 - acc: 0.8830 - val_loss: 0.7882 - val_acc: 0.5820
# Epoch 13/1000
# 58607/58607 [==============================] - 1s 17us/sample - loss: 0.3924 - acc: 0.8847 - val_loss: 0.7363 - val_acc: 0.6526
# Epoch 14/1000
# 58607/58607 [==============================] - 1s 17us/sample - loss: 0.3884 - acc: 0.8872 - val_loss: 0.7273 - val_acc: 0.6724
# Epoch 15/1000
# 58607/58607 [==============================] - 1s 17us/sample - loss: 0.3812 - acc: 0.8917 - val_loss: 0.6896 - val_acc: 0.6907
# Epoch 16/1000
# 57600/58607 [============================>.] - ETA: 0s - loss: 0.3745 - acc: 0.8981
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 58607/58607 [==============================] - 2s 28us/sample - loss: 0.3745 - acc: 0.8982 - val_loss: 0.6963 - val_acc: 0.6943
# Epoch 17/1000
# 58607/58607 [==============================] - 1s 16us/sample - loss: 0.3677 - acc: 0.9028 - val_loss: 0.7209 - val_acc: 0.6735
# Epoch 18/1000
# 58607/58607 [==============================] - 1s 16us/sample - loss: 0.3681 - acc: 0.9017 - val_loss: 0.7530 - val_acc: 0.6570
# Epoch 19/1000
# 58607/58607 [==============================] - 1s 16us/sample - loss: 0.3658 - acc: 0.9042 - val_loss: 0.6925 - val_acc: 0.7233
# Epoch 20/1000
# 58607/58607 [==============================] - 1s 16us/sample - loss: 0.3636 - acc: 0.9057 - val_loss: 0.7464 - val_acc: 0.6374
# Epoch 21/1000
# 58607/58607 [==============================] - 1s 16us/sample - loss: 0.3628 - acc: 0.9058 - val_loss: 0.6897 - val_acc: 0.6877
# Epoch 22/1000
# 56800/58607 [============================>.] - ETA: 0s - loss: 0.3611 - acc: 0.9059Restoring model weights from the end of the best epoch.
# 58607/58607 [==============================] - 2s 29us/sample - loss: 0.3611 - acc: 0.9060 - val_loss: 0.7436 - val_acc: 0.6515
# Epoch 00022: early stopping
# 0.6692307692307693 0.7222222222222222 0.8275862068965517
# ['GaCo08', 'GaCo22', 'GaPt17', 'GaPt31', 'JuPt01', 'JuPt04', 'JuPt12', 'JuPt17', 'SiCo11', 'SiCo13', 'SiCo17', 'SiCo19', 'SiCo28', 'SiPt05', 'SiPt27', 'SiPt33']
# Train on 60401 samples, validate on 5514 samples
# Epoch 1/1000
# 60401/60401 [==============================] - 3s 55us/sample - loss: 0.5743 - acc: 0.7264 - val_loss: 0.6459 - val_acc: 0.6649
# Epoch 2/1000
# 60401/60401 [==============================] - 1s 16us/sample - loss: 0.5064 - acc: 0.8013 - val_loss: 0.6614 - val_acc: 0.6650
# Epoch 3/1000
# 60401/60401 [==============================] - 1s 17us/sample - loss: 0.4814 - acc: 0.8222 - val_loss: 0.8003 - val_acc: 0.6300
# Epoch 4/1000
# 60401/60401 [==============================] - 1s 17us/sample - loss: 0.4624 - acc: 0.8367 - val_loss: 0.8231 - val_acc: 0.6242
# Epoch 5/1000
# 60401/60401 [==============================] - 1s 17us/sample - loss: 0.4461 - acc: 0.8482 - val_loss: 0.8470 - val_acc: 0.6400
# Epoch 6/1000
# 60401/60401 [==============================] - 1s 17us/sample - loss: 0.4378 - acc: 0.8549 - val_loss: 0.7940 - val_acc: 0.6496
# Epoch 7/1000
# 60401/60401 [==============================] - 1s 17us/sample - loss: 0.4228 - acc: 0.8645 - val_loss: 0.7107 - val_acc: 0.6534
# Epoch 8/1000
# 60401/60401 [==============================] - 1s 17us/sample - loss: 0.4170 - acc: 0.8684 - val_loss: 0.7735 - val_acc: 0.6460
# Epoch 9/1000
# 60401/60401 [==============================] - 1s 17us/sample - loss: 0.4078 - acc: 0.8735 - val_loss: 0.8350 - val_acc: 0.6418
# Epoch 10/1000
# 60401/60401 [==============================] - 1s 17us/sample - loss: 0.4063 - acc: 0.8753 - val_loss: 0.7461 - val_acc: 0.6632
# Epoch 11/1000
# 60401/60401 [==============================] - 1s 17us/sample - loss: 0.3974 - acc: 0.8817 - val_loss: 0.7404 - val_acc: 0.6708
# Epoch 12/1000
# 60401/60401 [==============================] - 1s 17us/sample - loss: 0.3925 - acc: 0.8858 - val_loss: 0.7399 - val_acc: 0.6652
# Epoch 13/1000
# 60401/60401 [==============================] - 1s 17us/sample - loss: 0.3849 - acc: 0.8909 - val_loss: 0.7931 - val_acc: 0.6469
# Epoch 14/1000
# 60401/60401 [==============================] - 1s 17us/sample - loss: 0.3778 - acc: 0.8974 - val_loss: 0.7177 - val_acc: 0.6913
# Epoch 15/1000
# 58400/60401 [============================>.] - ETA: 0s - loss: 0.3769 - acc: 0.8955
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 60401/60401 [==============================] - 2s 29us/sample - loss: 0.3769 - acc: 0.8953 - val_loss: 0.7553 - val_acc: 0.6834
# Epoch 16/1000
# 60401/60401 [==============================] - 1s 17us/sample - loss: 0.3656 - acc: 0.9041 - val_loss: 0.7365 - val_acc: 0.6824
# Epoch 17/1000
# 60401/60401 [==============================] - 1s 17us/sample - loss: 0.3607 - acc: 0.9071 - val_loss: 0.7477 - val_acc: 0.6727
# Epoch 18/1000
# 60401/60401 [==============================] - 1s 17us/sample - loss: 0.3570 - acc: 0.9111 - val_loss: 0.7564 - val_acc: 0.6828
# Epoch 19/1000
# 60401/60401 [==============================] - 1s 17us/sample - loss: 0.3580 - acc: 0.9106 - val_loss: 0.7290 - val_acc: 0.6806
# Epoch 20/1000
# 60401/60401 [==============================] - 1s 17us/sample - loss: 0.3563 - acc: 0.9116 - val_loss: 0.7428 - val_acc: 0.6765
# Epoch 21/1000
# 59200/60401 [============================>.] - ETA: 0s - loss: 0.3535 - acc: 0.9142Restoring model weights from the end of the best epoch.
# 60401/60401 [==============================] - 2s 31us/sample - loss: 0.3534 - acc: 0.9142 - val_loss: 0.7174 - val_acc: 0.6895
# Epoch 00021: early stopping
# 0.654320987654321 0.6666666666666666 0.7428571428571428
# ['GaCo10', 'GaCo17', 'GaPt04', 'GaPt15', 'GaPt16', 'JuCo03', 'JuCo19', 'JuPt09', 'SiCo05', 'SiCo26', 'SiCo27', 'SiPt02', 'SiPt13', 'SiPt30', 'SiPt34', 'SiPt40']
# Train on 59942 samples, validate on 5973 samples
# Epoch 1/1000
# 59942/59942 [==============================] - 3s 57us/sample - loss: 0.5663 - acc: 0.7386 - val_loss: 0.6372 - val_acc: 0.6777
# Epoch 2/1000
# 59942/59942 [==============================] - 1s 17us/sample - loss: 0.5207 - acc: 0.7886 - val_loss: 0.5813 - val_acc: 0.7053
# Epoch 3/1000
# 59942/59942 [==============================] - 1s 17us/sample - loss: 0.4981 - acc: 0.8073 - val_loss: 0.5108 - val_acc: 0.7691
# Epoch 4/1000
# 59942/59942 [==============================] - 1s 17us/sample - loss: 0.4803 - acc: 0.8226 - val_loss: 0.5480 - val_acc: 0.7338
# Epoch 5/1000
# 59942/59942 [==============================] - 1s 17us/sample - loss: 0.4594 - acc: 0.8360 - val_loss: 0.5210 - val_acc: 0.7499
# Epoch 6/1000
# 59942/59942 [==============================] - 1s 17us/sample - loss: 0.4464 - acc: 0.8469 - val_loss: 0.4571 - val_acc: 0.8122
# Epoch 7/1000
# 59942/59942 [==============================] - 1s 17us/sample - loss: 0.4433 - acc: 0.8487 - val_loss: 0.4430 - val_acc: 0.8312
# Epoch 8/1000
# 59942/59942 [==============================] - 1s 17us/sample - loss: 0.4273 - acc: 0.8593 - val_loss: 0.4009 - val_acc: 0.8798
# Epoch 9/1000
# 59942/59942 [==============================] - 1s 17us/sample - loss: 0.4210 - acc: 0.8628 - val_loss: 0.4125 - val_acc: 0.8721
# Epoch 10/1000
# 59942/59942 [==============================] - 1s 17us/sample - loss: 0.4118 - acc: 0.8709 - val_loss: 0.3860 - val_acc: 0.8808
# Epoch 11/1000
# 59942/59942 [==============================] - 1s 17us/sample - loss: 0.4065 - acc: 0.8741 - val_loss: 0.4197 - val_acc: 0.8632
# Epoch 12/1000
# 59942/59942 [==============================] - 1s 17us/sample - loss: 0.4007 - acc: 0.8791 - val_loss: 0.4145 - val_acc: 0.8694
# Epoch 13/1000
# 59942/59942 [==============================] - 1s 17us/sample - loss: 0.3954 - acc: 0.8822 - val_loss: 0.4190 - val_acc: 0.8639
# Epoch 14/1000
# 59942/59942 [==============================] - 1s 17us/sample - loss: 0.3930 - acc: 0.8836 - val_loss: 0.3885 - val_acc: 0.8887
# Epoch 15/1000
# 59942/59942 [==============================] - 1s 17us/sample - loss: 0.3878 - acc: 0.8872 - val_loss: 0.3817 - val_acc: 0.8962
# Epoch 16/1000
# 59942/59942 [==============================] - 1s 17us/sample - loss: 0.3825 - acc: 0.8907 - val_loss: 0.3961 - val_acc: 0.8741
# Epoch 17/1000
# 59942/59942 [==============================] - 1s 17us/sample - loss: 0.3779 - acc: 0.8929 - val_loss: 0.4349 - val_acc: 0.8614
# Epoch 18/1000
# 59942/59942 [==============================] - 1s 17us/sample - loss: 0.3767 - acc: 0.8956 - val_loss: 0.4129 - val_acc: 0.8666
# Epoch 19/1000
# 59942/59942 [==============================] - 1s 17us/sample - loss: 0.3734 - acc: 0.8971 - val_loss: 0.4104 - val_acc: 0.8625
# Epoch 20/1000
# 59942/59942 [==============================] - 1s 17us/sample - loss: 0.3687 - acc: 0.9003 - val_loss: 0.4016 - val_acc: 0.8661
# Epoch 21/1000
# 59942/59942 [==============================] - 1s 17us/sample - loss: 0.3687 - acc: 0.8999 - val_loss: 0.4072 - val_acc: 0.8708
# Epoch 22/1000
# 59942/59942 [==============================] - 1s 17us/sample - loss: 0.3626 - acc: 0.9053 - val_loss: 0.3875 - val_acc: 0.8915
# Epoch 23/1000
# 59942/59942 [==============================] - 1s 17us/sample - loss: 0.3638 - acc: 0.9044 - val_loss: 0.4022 - val_acc: 0.8641
# Epoch 24/1000
# 59942/59942 [==============================] - 1s 17us/sample - loss: 0.3604 - acc: 0.9063 - val_loss: 0.4139 - val_acc: 0.8599
# Epoch 25/1000
# 59942/59942 [==============================] - 1s 17us/sample - loss: 0.3585 - acc: 0.9086 - val_loss: 0.4024 - val_acc: 0.8676
# Epoch 26/1000
# 59942/59942 [==============================] - 1s 17us/sample - loss: 0.3535 - acc: 0.9119 - val_loss: 0.4102 - val_acc: 0.8674
# Epoch 27/1000
# 59942/59942 [==============================] - 1s 17us/sample - loss: 0.3557 - acc: 0.9099 - val_loss: 0.4130 - val_acc: 0.8671
# Epoch 28/1000
# 59942/59942 [==============================] - 1s 17us/sample - loss: 0.3517 - acc: 0.9130 - val_loss: 0.4205 - val_acc: 0.8595
# Epoch 29/1000
# 56000/59942 [===========================>..] - ETA: 0s - loss: 0.3492 - acc: 0.9145
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 59942/59942 [==============================] - 2s 32us/sample - loss: 0.3488 - acc: 0.9146 - val_loss: 0.4048 - val_acc: 0.8692
# Epoch 30/1000
# 56800/59942 [===========================>..] - ETA: 0s - loss: 0.3403 - acc: 0.9213Restoring model weights from the end of the best epoch.
# 59942/59942 [==============================] - 2s 32us/sample - loss: 0.3399 - acc: 0.9217 - val_loss: 0.4153 - val_acc: 0.8687
# Epoch 00030: early stopping
# 1.0 0.9629629629629629 0.9714285714285714
# AUC		 0.8767719684368235 0.11459284905420726
# Accuracy	 0.8360267286991425 0.09724506598629583
# F1Score		 0.8870083314129762 0.06999558449449074

# %%
print ("AUC\t\t",np.mean(AUC),np.std(AUC))
print ("Accuracy\t",np.mean(accuracy),np.std(accuracy))
print ("F1Score\t\t",np.mean(F1Score),np.std(F1Score))
# Out:
# AUC		 0.8767719684368235 0.11459284905420726
# Accuracy	 0.8360267286991425 0.09724506598629583
# F1Score		 0.8870083314129762 0.06999558449449074

# %%
full_model.summary()
# Out:
# Model: "model_28"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_29 (InputLayer)        [(None, None, 18)]        0
# _________________________________________________________________
# spatial_dropout1d_9 (Spatial (None, None, 18)          0
# _________________________________________________________________
# conv1d_99 (Conv1D)           (None, None, 32)          4064
# _________________________________________________________________
# batch_normalization_27 (Batc (None, None, 32)          128
# _________________________________________________________________
# activation_18 (Activation)   (None, None, 32)          0
# _________________________________________________________________
# max_pooling1d_54 (MaxPooling (None, None, 32)          0
# _________________________________________________________________
# conv1d_100 (Conv1D)          (None, None, 32)          5152
# _________________________________________________________________
# batch_normalization_28 (Batc (None, None, 32)          128
# _________________________________________________________________
# activation_19 (Activation)   (None, None, 32)          0
# _________________________________________________________________
# max_pooling1d_55 (MaxPooling (None, None, 32)          0
# _________________________________________________________________
# conv1d_101 (Conv1D)          (None, None, 64)          6208
# _________________________________________________________________
# batch_normalization_29 (Batc (None, None, 64)          256
# _________________________________________________________________
# embedding (Activation)       (None, None, 64)          0
# _________________________________________________________________
# global_average_pooling1d_9 ( (None, 64)                0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 64)                0
# _________________________________________________________________
# det (Dense)                  (None, 1)                 65
# =================================================================
# Total params: 16,001
# Trainable params: 15,745
# Non-trainable params: 256
# _________________________________________________________________

# %%
gt = np.array(gold)
pre = np.array(predictions)

# %%
roc_auc_score(gt,pre)
# Out:
# 0.8918630637952052
